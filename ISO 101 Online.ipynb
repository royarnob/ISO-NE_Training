# %% [markdown]
# What is the name of the part of the power system that ISO New England administers, also known as the bulk electric system?
#
# **Answer:** Transmission

# %% [markdown]
# ![ISO New England Industry Structure](iso_ne_industry_structure.png)

# %% [markdown]
# **Knowledge Check**
# What are the **three** primary responsibilities of ISO New England?
#
# - Power system planning
# - Operating the power system
# - Administering wholesale electricity markets
#
# What is the term for the transmission lines that connect New England to New York and Canada?
#
# - Interconnections
#
# What are the names of the **two** energy markets in New England?
#
# - Day-Ahead Market
# - Real-Time Market
